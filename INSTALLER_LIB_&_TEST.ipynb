# %% [markdown]
# <a href="https://colab.research.google.com/github/FabioBiit/ML_SCRIPTS/blob/main/INSTALLER_LIB_%26_TEST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **INSTALLER LIBRERIE**

# %%
#! pip install -q tensorflow

# %%
#! pip install scikit-learn
