# %% [markdown]
# ### **INSTALLER LIBRERIE**

# %%
#! pip install -q tensorflow

# %%
#! pip install scikit-learn

# %% [markdown]
# ### **TEST**

# %%
#! nvidia-smi
# Out:
# Sat Dec 27 15:51:07 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 581.57                 Driver Version: 581.57         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3080 ...  WDDM  |   00000000:01:00.0  On |                  N/A |
# | N/A   45C    P8             10W /  100W |     891MiB /   8192MiB |      1%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2848    C+G   ...INDOWS\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A            4412    C+G   ...s Service\ePowerButton_NB.exe      N/A      |
# |    0   N/A  N/A            4952    C+G   C:\WINDOWS\explorer.exe               N/A      |
# |    0   N/A  N/A            9352    C+G   ...em32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A           11492    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A           12024    C+G   ...IA app\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           12280    C+G   ...IA app\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           13640    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           13664    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           13820    C+G   ...cw5n1h2txyewy\WidgetBoard.exe      N/A      |
# |    0   N/A  N/A           15280    C+G   ....0.3650.96\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           18348    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           18788    C+G   ...a\Roaming\Spotify\Spotify.exe      N/A      |
# |    0   N/A  N/A           20872    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           24988    C+G   ...icrosoft.AAD.BrokerPlugin.exe      N/A      |
# |    0   N/A  N/A           25276    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           25480    C+G   ...Acrobat\acrocef_2\AcroCEF.exe      N/A      |
# |    0   N/A  N/A           25744    C+G   ....0.3650.96\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           29060    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A           30456    C+G   ...ms\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A           32040    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# print("Hello World")

# %% [markdown]
# ### **TEST METRICHE**

# %%
import sklearn

# SET DATI
gt = [1,1,0,0,0,1,1]
pred = [1,1,1,0,0,0,1]

# CLASSIFICAZIONE
f1 = sklearn.metrics.f1_score(gt, pred)
print(f"\nF1_Score: {f1}")

accuracy = round(sklearn.metrics.accuracy_score(gt, pred), 2)
print(f"\nAccuracy: {accuracy}")

precision = sklearn.metrics.precision_score(gt, pred)
print(f"\nPrecison: {precision}")

recall = sklearn.metrics.recall_score(gt, pred)
print(f"\nRecall: {recall}")

# REGRESSIONE
mean = round(sklearn.metrics.mean_absolute_error(gt, pred), 2)
print(f"\nMean Absolute Error: {mean}")

mean_err = round(sklearn.metrics.mean_squared_error(gt, pred), 2)
print(f"\nMean Squared Error: {mean_err}")
# Out:
# F1_Score: 0.75
#
# Accuracy: 0.71
#
# Precison: 0.75
#
# Recall: 0.75
#
# Mean Absolute Error: 0.29
#
# Mean Squared Error: 0.29
